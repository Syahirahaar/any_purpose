# %%
poke_stats = [[90,92,75,60],[25,20,15,89],[65,130,60,75]]

# %%
# %%timeit
totals = []
for row in poke_stats:
    totals.append(sum(row))

# %%
# %timeit totals_comp = [sum(row) for row in poke_stats]

# %%
# %timeit totals_map = [*map(sum,poke_stats)]

# %%
print(totals_map)

# %%
poke_names = ('ac','ds')
poke_gen = (1,2)

# %%
gen1_gen2_pokemon = [name for name,gen in zip(poke_names,poke_gen) if gen < 3]

# %%
print(gen1_gen2_pokemon)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('C:/Users/Syahirahar/Desktop/IDEAS ICERD_2000 (Responses) - Form Responses 1.csv')

# %%
df.head()
# Out:
#           Timestamp                EMAIL 1. Phone number  - Copy from ARIA  \
# 0  2/5/2020 9:12:58  miza2497@gmail.com                        60147363607
# 1  2/5/2020 9:14:41  miza2497@gmail.com                        60139585605
# 2  2/5/2020 9:16:39  miza2497@gmail.com                        60148440635
# 3  2/5/2020 9:17:44   erna_ash@yahoo.com                       60179657470
# 4  2/5/2020 9:17:50  miza2497@gmail.com                        60106619307
#
#   Q1Pernahkah anda mendengar tentang Konvensyen Antarabangsa Mengenai Penghapusan Segala Bentuk Diskriminasi Kaum atau lebih dikenali sebagai ICERD?/Have you heard about the International Convention on the Elimination of all forms of Racial Discrimination also known as ICERD?/  \
# 0                                                NaN
# 1                                           Ya / Yes
# 2                                                NaN
# 3                   Tidak/Tidak pasti / No /Not Sure
# 4                                                NaN
#
#   Q2Dari manakah sumber utama anda mendapat maklumat tentang ICERD?/Where did you mainly get information about ICERD?/  \
# 0                                                NaN
# 1  Media sosial / Social media (cth: Facebook, Tw...
# 2                                                NaN
# 3                                               NONE
# 4                                                NaN
#
#   Q3Bilakah kali terakhir anda mendengar berita atau perbincangan tentang ICERD?/ (Dalam tempoh..)When was the last time you heard of any news or discussion about ICERD?/ (Within..)  \
# 0                                                NaN
# 1                     Setahun yang lalu / A year ago
# 2                                                NaN
# 3                                               NONE
# 4                                                NaN
#
#   Q4Antara pilihan berikut, apakah matlamat yang ingin dicapai melalui ICERD?/ From the following, what is the objective of ICERD?/  \
# 0                                                NaN
# 1  Tidak tahu/Tidak pasti/Lain-lain / Don’t know/...
# 2                                                NaN
# 3  Menghapuskan segala bentuk diskriminasi kaum /...
# 4                                                NaN
#
#   Q5Antara pilihan berikut, pihak manakah yang telah mengusulkan ICERD?/Who do you think proposed ICERD from the following options?/  \
# 0                                                NaN
# 1  Tidak tahu/Tidak pasti/Lain-lain / Don’t know/...
# 2                                                NaN
# 3  Pertubuhan Bangsa-bangsa Bersatu / United Nations
# 4                                                NaN
#
#   Q6Berapakah jumlah negara yang telah meratifikasi ICERD di seluruh dunia?/How many countries around the world have ratified ICERD?/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                181
# 4                                                NaN
#
#   Q7Secara umumnya, adakah anda bersetuju dengan kenyataan bahawa “Ratifikasi ICERD akan membawa lebih banyak kebaikan berbanding keburukan”?/In general, do you agree with the statement that “Ratification of ICERD will bring more benefit than harm”?/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                     Setuju / Agree
# 4                                                NaN
#
#    ... Q24Gender   Q25Ethnicity  Q26Age - NUMBER ONLY  \
# 0  ...       NaN             NaN                  NaN
# 1  ...       NaN             NaN                  NaN
# 2  ...       NaN             NaN                  NaN
# 3  ...         L  Melayu / Malay                 45.0
# 4  ...       NaN             NaN                  NaN
#
#   Q27Apakah tahap pendidikan tertinggi yang anda miliki?/What is your highest education level?/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                          PMR/PT3/SPM/Diploma/Sijil
# 4                                                NaN
#
#   Q28Anda seorang graduan universiti tempatan atau luar negara?/Are you a local or overseas graduate?/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                   Tempatan / local
# 4                                                NaN
#
#   Q29Apakah pekerjaan anda sekarang?/What is your current occupation?/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3           Bekerja/berniaga sendiri / Self-employed
# 4                                                NaN
#
#   Q30Dalam kategori manakah pendapatan bulanan anda?/Which monthly income category do you fall into?/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                               RM 5,001 - RM 10,000
# 4                                                NaN
#
#   Q31Lokasi tempat tinggal anda di NEGERI mana?   \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                       KELANTAN
# 4                                            NaN
#
#   Q32Anda tinggal di kawasan bandar atau luar bandar?/Do you live in an urban or rural area?/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                      Luar bandar (kampung) / rural
# 4                                                NaN
#
#   Panggilan terputus
# 0          Voicemail
# 1            Hang Up
# 2           Rejected
# 3                NaN
# 4           Rejected
#
# [5 rows x 36 columns]

# %%
#df.columns.values[3] = "q1"
#df["q1"].replace('', np.nan,inplace=True)
#df.dropna(subset=['q1'],inplace=True)
    
df.columns.values[2] = "Phonenum"
df.columns.values[26] = "gender"
df.columns.values[27] = "eth"
df.columns.values[28] = "age"
df.columns.values[29] = "edu"
df.columns.values[31] = "occ"
df.columns.values[32] = "income"

# %%
df=df.dropna()

# %%
df.head()

# %%
df["eth_1"] = df["eth"].str.split("/").str[0]
